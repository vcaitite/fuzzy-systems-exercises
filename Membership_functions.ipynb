# %% [markdown]
# # Membership Functions

# %%
import skfuzzy as fuzz
import numpy as np
from matplotlib import pyplot as plt
from math import *

# %% [markdown]
# ## PART 1 - Using Skfuzzy

# %% [markdown]
# ### Triangular Membership Function

# %%
x = np.linspace(0, 10, 500)
y1 = fuzz.trimf(x, [3, 4, 5])
y2 = fuzz.trimf(x, [2, 4, 7])
y3 = fuzz.trimf(x, [1, 4, 9])
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$'])

# %% [markdown]
# ### Trapezoidal Membership Function

# %%
x = np.linspace(0, 10, 500)
y1 = fuzz.trapmf(x, [2, 3, 7, 9])
y2 = fuzz.trapmf(x, [3, 4, 6, 8])
y3 = fuzz.trapmf(x, [4, 5, 5, 7])
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$'])

# %% [markdown]
# ### Gaussian Fuzzy Membership Function

# %%
x = np.linspace(0, 10, 500)
# gaussmf(x, mean, sigma)
y1 = fuzz.gaussmf(x, 5, 0.5)
y2 = fuzz.gaussmf(x, 5, 1)
y3 = fuzz.gaussmf(x, 5, 2)
y4 = fuzz.gaussmf(x, 5, 3)
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %%
# gaussmf(x, mean, sigma)
y1 = fuzz.gaussmf(x, 2, 1)
y2 = fuzz.gaussmf(x, 4, 1)
y3 = fuzz.gaussmf(x, 6, 1)
y4 = fuzz.gaussmf(x, 8, 1)
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %% [markdown]
# ### Generalized Bell Function

# %%
# gbellmf(x, a, b, c)
x = np.linspace(0, 10, 500)
y1 = fuzz.gbellmf(x, 1, 2, 5)
y2 = fuzz.gbellmf(x, 2, 4, 5)
y3 = fuzz.gbellmf(x, 3, 6, 5)
y4 = fuzz.gbellmf(x, 4, 8, 5) 
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %%
# gbellmf(x, a, b, c)
x = np.linspace(0, 10, 500)
y1 = fuzz.gbellmf(x, 2, 1, 5)
y2 = fuzz.gbellmf(x, 2, 2, 5)
y3 = fuzz.gbellmf(x, 2, 4, 5)
y4 = fuzz.gbellmf(x, 2, 8, 5) 
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %% [markdown]
# ### Sigmoidal Function

# %%
# sigmf(x, c, a)
x = np.linspace(0, 10, 500)
y1 = fuzz.sigmf(x, 5, -1)
y2 = fuzz.sigmf(x, 5, -3)
y3 = fuzz.sigmf(x, 5, 4)
y4 = fuzz.sigmf(x, 5, 8) 
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %%
# sigmf(x, c, a)
x = np.linspace(0, 10, 500)
y1 = fuzz.sigmf(x, 2, 5)
y2 = fuzz.sigmf(x, 4, 5)
y3 = fuzz.sigmf(x, 6, 5)
y4 = fuzz.sigmf(x, 8, 5) 
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %% [markdown]
# ## PART 2 - Creating my own Membership Functions

# %%
def trimf(x,a,b,c):
    y = np.zeros(len(x))
    for i in range(len(x)):
        y[i] = max([min([(x[i]-a)/(b-a), (c-x[i])/(c-b)]), 0])
    return y

def gaussmf(x,c,sigma):
    return e**(-1/2 * ((x-c)/sigma)**2)

def trapmf(x,a,b,c,d):
    y = np.zeros(len(x))
    for i in range(len(x)):
        if x[i] > a and x[i] <= b:
            y[i] = (x[i]-a)/(b-a)
        if x[i] > b and x[i] <= c:
            y[i] = 1
        if x[i] > c and x[i] < d:
            y[i] = (-x[i]+d)/(-c+d)
    return y

def gbellmf(x, a, b, c):
    return 1/(1+abs(((x-c)/a)**(2*b)))

def sigmf(x, c, a):
    return 1/(1 + e**(-a*(x-c)))

# %% [markdown]
# ### Triangular Membership Function

# %%
x = np.linspace(0, 10, 500)
y1 = trimf(x, 3, 4, 5)
y2 = trimf(x, 2, 4, 7)
y3 = trimf(x, 1, 4, 9)
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$'])

# %% [markdown]
# ### Trapezoidal Membership Function

# %%
x = np.linspace(0, 10, 500)
y1 = trapmf(x, 2, 3, 7, 9)
y2 = trapmf(x, 3, 4, 6, 8)
y3 = trapmf(x, 4, 5, 5, 7)
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$'])

# %% [markdown]
# ### Gaussian Fuzzy Membership Function

# %%
x = np.linspace(0, 10, 500)
# gaussmf(x, mean, sigma)
y1 = gaussmf(x, 5, 0.5)
y2 = gaussmf(x, 5, 1)
y3 = gaussmf(x, 5, 2)
y4 = gaussmf(x, 5, 3)
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %%
# gaussmf(x, mean, sigma)
y1 = fuzz.gaussmf(x, 2, 1)
y2 = fuzz.gaussmf(x, 4, 1)
y3 = fuzz.gaussmf(x, 6, 1)
y4 = fuzz.gaussmf(x, 8, 1)
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %% [markdown]
# ### Generalized Bell Function

# %%
# gbellmf(x, a, b, c)
x = np.linspace(0, 10, 500)
y1 = gbellmf(x, 1, 2, 5)
y2 = gbellmf(x, 2, 4, 5)
y3 = gbellmf(x, 3, 6, 5)
y4 = gbellmf(x, 4, 8, 5) 
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %%
# gbellmf(x, a, b, c)
x = np.linspace(0, 10, 500)
y1 = gbellmf(x, 2, 1, 5)
y2 = gbellmf(x, 2, 2, 5)
y3 = gbellmf(x, 2, 4, 5)
y4 = gbellmf(x, 2, 8, 5) 
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %% [markdown]
# ### Sigmoidal Function

# %%
# sigmf(x, c, a)
x = np.linspace(0, 10, 500)
y1 = sigmf(x, 5, -1)
y2 = sigmf(x, 5, -3)
y3 = sigmf(x, 5, 4)
y4 = sigmf(x, 5, 8) 
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])

# %%
# sigmf(x, c, a)
x = np.linspace(0, 10, 500)
y1 = fuzz.sigmf(x, 2, 5)
y2 = fuzz.sigmf(x, 4, 5)
y3 = fuzz.sigmf(x, 6, 5)
y4 = fuzz.sigmf(x, 8, 5) 
plt.plot(x, y1, 'b-',x, y2,'r-', x, y3, 'g-', x, y4, 'y-')
plt.grid()
legend = plt.legend([r'$y_1$', r'$y_2$', r'$y_3$', r'$y_4$'])
